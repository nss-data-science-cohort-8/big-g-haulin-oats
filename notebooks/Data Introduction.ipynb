# %%
import pandas as pd

# %%
faults = pd.read_csv("../data/J1939Faults.csv")
faults.head()
# Out:
# C:\Users\irela\AppData\Local\Temp\ipykernel_28300\3681478151.py:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   faults = pd.read_csv("../data/J1939Faults.csv")
#    RecordID  ESS_Id           EventTimeStamp  \
# 0         1  990349  2015-02-21 10:47:13.000
# 1         2  990360  2015-02-21 11:34:34.000
# 2         3  990364  2015-02-21 11:35:31.000
# 3         4  990370  2015-02-21 11:35:33.000
# 4         5  990416  2015-02-21 11:39:41.000
#
#                           eventDescription  actionDescription  \
# 0  Low (Severity Low) Engine Coolant Level                NaN
# 1                                      NaN                NaN
# 2      Incorrect Data Steering Wheel Angle                NaN
# 3      Incorrect Data Steering Wheel Angle                NaN
# 4                                      NaN                NaN
#
#                      ecuSoftwareVersion ecuSerialNumber              ecuModel  \
# 0                               unknown         unknown               unknown
# 1                               unknown         unknown               unknown
# 2                               unknown         unknown               unknown
# 3                               unknown         unknown               unknown
# 4  22281684P01*22357957P01*22362082P01*        13063430  0USA13_13_0415_2238A
#
#    ecuMake  ecuSource   spn  fmi  active  activeTransitionCount  faultValue  \
# 0  unknown          0   111   17    True                      2         NaN
# 1  unknown         11   629   12    True                    127         NaN
# 2  unknown         11  1807    2   False                    127         NaN
# 3  unknown         11  1807    2    True                    127         NaN
# 4    VOLVO          0  4364   17   False                      2         NaN
#
#   EquipmentID  MCTNumber   Latitude  Longitude        LocationTimeStamp
# 0        1439  105354361  38.857638 -84.626851  2015-02-21 11:34:25.000
# 1        1439  105354361  38.857638 -84.626851  2015-02-21 11:35:10.000
# 2        1369  105336226  41.421250 -87.767361  2015-02-21 11:35:26.000
# 3        1369  105336226  41.421018 -87.767361  2015-02-21 11:36:08.000
# 4        1674  105427130  38.416481 -89.442638  2015-02-21 11:39:37.000

# %%
faults.loc[0]
# Out:
# RecordID                                                       1
# ESS_Id                                                    990349
# EventTimeStamp                           2015-02-21 10:47:13.000
# eventDescription         Low (Severity Low) Engine Coolant Level
# actionDescription                                            NaN
# ecuSoftwareVersion                                       unknown
# ecuSerialNumber                                          unknown
# ecuModel                                                 unknown
# ecuMake                                                  unknown
# ecuSource                                                      0
# spn                                                          111
# fmi                                                           17
# active                                                      True
# activeTransitionCount                                          2
# faultValue                                                   NaN
# EquipmentID                                                 1439
# MCTNumber                                              105354361
# Latitude                                               38.857638
# Longitude                                             -84.626851
# LocationTimeStamp                        2015-02-21 11:34:25.000
# Name: 0, dtype: object

# %% [markdown]
# Looking at the first record, here is a breakdown of the important values.
#
# * ESS_Id, actionDescription, ecuSoftwareVersion, ecuSerialNumber, ecuModel, ecuMake, ecuSource, faultValue, and MCTNumber are unlikely to provide any predictive value.
# * We can see the time of the event in the **EventTimeStamp** column. Note that this may be different from the **LocationTimeStamp** value, which indicates when the Latitude/Longitude values were recorded.
# * The **spn** and **fmi** columns together indicate the type of fault, and there may be a description of that fault in the **eventDescription** column, although this column is sometimes missing.
# * Faults are recorded when the light goes on and when it goes off, which is indicated by the **active** column, with True indicating the light turning on and False indicating turning off. The number of times the code has been set or unset is in the **faultValue** column, although this value can be unreliable.
# * Each truck has an identifier, the **EquipmentID** value.
# * Each record can be linked to the on-board diagnostics data through the **RecordID** column.

# %%
diagnostics = pd.read_csv("../data/VehicleDiagnosticOnboardData.csv")
diagnostics = diagnostics.pivot(index='FaultId', columns='Name', values='Value')
diagnostics.head()
# Out:
# Name    AcceleratorPedal BarometricPressure CruiseControlActive  \
# FaultId
# 1                      0              14.21               False
# 2                    NaN                NaN                 NaN
# 3                    NaN                NaN                 NaN
# 4                    NaN                NaN                 NaN
# 5                    NaN                NaN                 NaN
#
# Name    CruiseControlSetSpeed DistanceLtd EngineCoolantTemperature EngineLoad  \
# FaultId
# 1                    66.48672    423178.7                    100.4         11
# 2                         NaN         NaN                      NaN        NaN
# 3                         NaN         NaN                      NaN        NaN
# 4                         NaN         NaN                      NaN        NaN
# 5                         NaN         NaN                      NaN        NaN
#
# Name    EngineOilPressure EngineOilTemperature EngineRpm  ... FuelTemperature  \
# FaultId                                                   ...
# 1                       0             96.74375         0  ...             NaN
# 2                     NaN                  NaN       NaN  ...             NaN
# 3                     NaN                  NaN       NaN  ...             NaN
# 4                     NaN                  NaN       NaN  ...             NaN
# 5                     NaN                  NaN       NaN  ...             NaN
#
# Name    IgnStatus IntakeManifoldTemperature LampStatus ParkingBrake  \
# FaultId
# 1           False                      78.8       1023         True
# 2            True                       NaN       1279          NaN
# 3             NaN                       NaN       1279          NaN
# 4            True                       NaN       1279          NaN
# 5             NaN                       NaN      16639          NaN
#
# Name    ServiceDistance Speed SwitchedBatteryVoltage Throttle  \
# FaultId
# 1                   NaN     0                3276.75      NaN
# 2                   NaN   NaN                    NaN      NaN
# 3                   NaN   NaN                    NaN      NaN
# 4                   NaN   NaN                    NaN      NaN
# 5                   NaN   NaN                    NaN      NaN
#
# Name    TurboBoostPressure
# FaultId
# 1                        0
# 2                      NaN
# 3                      NaN
# 4                      NaN
# 5                      NaN
#
# [5 rows x 24 columns]

# %%
faults_and_diagnostics = faults.merge(diagnostics, how='left', left_on='RecordID', right_on='FaultId')
faults_and_diagnostics.head()
# Out:
#    RecordID  ESS_Id           EventTimeStamp  \
# 0         1  990349  2015-02-21 10:47:13.000
# 1         2  990360  2015-02-21 11:34:34.000
# 2         3  990364  2015-02-21 11:35:31.000
# 3         4  990370  2015-02-21 11:35:33.000
# 4         5  990416  2015-02-21 11:39:41.000
#
#                           eventDescription  actionDescription  \
# 0  Low (Severity Low) Engine Coolant Level                NaN
# 1                                      NaN                NaN
# 2      Incorrect Data Steering Wheel Angle                NaN
# 3      Incorrect Data Steering Wheel Angle                NaN
# 4                                      NaN                NaN
#
#                      ecuSoftwareVersion ecuSerialNumber              ecuModel  \
# 0                               unknown         unknown               unknown
# 1                               unknown         unknown               unknown
# 2                               unknown         unknown               unknown
# 3                               unknown         unknown               unknown
# 4  22281684P01*22357957P01*22362082P01*        13063430  0USA13_13_0415_2238A
#
#    ecuMake  ecuSource  ...  FuelTemperature  IgnStatus  \
# 0  unknown          0  ...              NaN      False
# 1  unknown         11  ...              NaN       True
# 2  unknown         11  ...              NaN        NaN
# 3  unknown         11  ...              NaN       True
# 4    VOLVO          0  ...              NaN        NaN
#
#    IntakeManifoldTemperature  LampStatus  ParkingBrake ServiceDistance  Speed  \
# 0                       78.8        1023          True             NaN      0
# 1                        NaN        1279           NaN             NaN    NaN
# 2                        NaN        1279           NaN             NaN    NaN
# 3                        NaN        1279           NaN             NaN    NaN
# 4                        NaN       16639           NaN             NaN    NaN
#
#    SwitchedBatteryVoltage  Throttle TurboBoostPressure
# 0                 3276.75       NaN                  0
# 1                     NaN       NaN                NaN
# 2                     NaN       NaN                NaN
# 3                     NaN       NaN                NaN
# 4                     NaN       NaN                NaN
#
# [5 rows x 44 columns]

# %% [markdown]
# To get the on-board diagnostics at the time of the fault code, we can match the **RecordID** to the **FaultId**.

# %%
faults_and_diagnostics.loc[faults_and_diagnostics['spn'] == 5246]
# Out:
#          RecordID     ESS_Id           EventTimeStamp eventDescription  \
# 45             46     990931  2015-02-21 12:10:51.000              NaN
# 1918         1919    1007751  2015-02-22 19:44:55.000              NaN
# 2058         2059    1010486  2015-02-23 04:00:21.000              NaN
# 2089         2090    1011009  2015-02-23 05:05:44.000              NaN
# 2971         2972    1026305  2015-02-23 15:54:22.000              NaN
# ...           ...        ...                      ...              ...
# 1183032   1244156  121610128  2020-02-19 07:02:33.000              NaN
# 1183684   1244808  121909497  2020-02-21 07:23:44.000              NaN
# 1184328   1245452  122305094  2020-02-24 15:28:05.000              NaN
# 1184330   1245454  122305096  2020-02-24 15:27:26.000              NaN
# 1185275   1246399  122740697  2020-02-27 12:11:33.000              NaN
#
#          actionDescription                               ecuSoftwareVersion  \
# 45                     NaN  04993120*00027849*082113134117*07700053*I0*BBZ*
# 1918                   NaN  04993120*00027849*082113134117*07700053*I0*BBZ*
# 2058                   NaN  04993120*00027849*082113134117*07700053*I0*BBZ*
# 2089                   NaN  05290170*03015749*051914190353*09400015*G1*BDR*
# 2971                   NaN                                          unknown
# ...                    ...                                              ...
# 1183032                NaN  05317106*05005224*051718172255*09401583*G1*BDR*
# 1183684                NaN  04384413*22246857*090619141107*60701756*G1*BGT*
# 1184328                NaN  04384413*22246857*090619141107*60701756*G1*BGT*
# 1184330                NaN  04384413*22246857*090619141107*60701756*G1*BGT*
# 1185275                NaN  04384413*22246857*090619141107*60701756*G1*BGT*
#
#         ecuSerialNumber           ecuModel  ecuMake  ecuSource  ...  \
# 45             79464664  6X1u10D1500000000    CMMNS          0  ...
# 1918           79464664  6X1u10D1500000000    CMMNS          0  ...
# 2058           79464664  6X1u10D1500000000    CMMNS          0  ...
# 2089           79642446  6X1u13D1500000000    CMMNS          0  ...
# 2971            unknown            unknown  unknown          0  ...
# ...                 ...                ...      ...        ...  ...
# 1183032        79845785  6X1u13D1500000000    CMMNS          0  ...
# 1183684        80092582  6X1u17D1500000000    CMMNS          0  ...
# 1184328        80092582  6X1u17D1500000000    CMMNS          0  ...
# 1184330        80092582  6X1u17D1500000000    CMMNS          0  ...
# 1185275        80092582  6X1u17D1500000000    CMMNS          0  ...
#
#          activeTransitionCount  faultValue  EquipmentID  MCTNumber   Latitude  \
# 45                           1         NaN         1395  105349612  36.065972
# 1918                         1         NaN         1395  105349612  36.066203
# 2058                         1         NaN         1395  105349612  36.066666
# 2089                         1         NaN         1630  105329900  40.733009
# 2971                         1         NaN         1487  105369355  28.077361
# ...                        ...         ...          ...        ...        ...
# 1183032                      1         NaN         1814  105369518  36.067037
# 1183684                      1         NaN         2211  105329862  36.066296
# 1184328                      1         NaN         2211  105329862  36.066620
# 1184330                      1         NaN         2211  105329862  36.066620
# 1185275                      1         NaN         2211  105329862  36.066296
#
#          Longitude        LocationTimeStamp                       Name  \
# 45      -86.433425  2015-02-21 12:11:27.000     SwitchedBatteryVoltage
# 1918    -86.434814  2015-02-22 19:46:27.000          EngineOilPressure
# 2058    -86.434537  2015-02-23 01:06:06.000         BarometricPressure
# 2089    -74.087777  2015-02-23 05:08:23.000          EngineOilPressure
# 2971    -81.897083  2015-02-23 15:54:58.000                 EngineLoad
# ...            ...                      ...                        ...
# 1183032 -86.434120  2020-02-19 07:03:09.000  IntakeManifoldTemperature
# 1183684 -86.434305  2020-02-21 07:24:20.000         TurboBoostPressure
# 1184328 -86.434722  2020-02-24 15:28:01.000      CruiseControlSetSpeed
# 1184330 -86.434722  2020-02-24 15:28:02.000   EngineCoolantTemperature
# 1185275 -86.434490  2020-02-27 12:11:29.000                 LampStatus
#
#             Value   FaultId
# 45        3276.75       6.0
# 1918        38.28     212.0
# 2058        13.92     226.0
# 2089        19.72     229.0
# 2971           32     324.0
# ...           ...       ...
# 1183032     132.8  123386.0
# 1183684     30.74  123456.0
# 1184328  66.48672  123524.0
# 1184330       185  123524.0
# 1185275      1279  123621.0
#
# [1195 rows x 23 columns]

# %%
faults_and_diagnostics['FullDerate'] = faults_and_diagnostics['spn'].apply(lambda x: 1 if x == 5246 else 0)
faults_and_diagnostics.head()
# Out:
#    RecordID  ESS_Id           EventTimeStamp  \
# 0         1  990349  2015-02-21 10:47:13.000
# 1         2  990360  2015-02-21 11:34:34.000
# 2         3  990364  2015-02-21 11:35:31.000
# 3         4  990370  2015-02-21 11:35:33.000
# 4         5  990416  2015-02-21 11:39:41.000
#
#                           eventDescription  actionDescription  \
# 0  Low (Severity Low) Engine Coolant Level                NaN
# 1                                      NaN                NaN
# 2      Incorrect Data Steering Wheel Angle                NaN
# 3      Incorrect Data Steering Wheel Angle                NaN
# 4                                      NaN                NaN
#
#                      ecuSoftwareVersion ecuSerialNumber              ecuModel  \
# 0                               unknown         unknown               unknown
# 1                               unknown         unknown               unknown
# 2                               unknown         unknown               unknown
# 3                               unknown         unknown               unknown
# 4  22281684P01*22357957P01*22362082P01*        13063430  0USA13_13_0415_2238A
#
#    ecuMake  ecuSource  ...  faultValue  EquipmentID  MCTNumber   Latitude  \
# 0  unknown          0  ...         NaN         1439  105354361  38.857638
# 1  unknown         11  ...         NaN         1439  105354361  38.857638
# 2  unknown         11  ...         NaN         1369  105336226  41.421250
# 3  unknown         11  ...         NaN         1369  105336226  41.421018
# 4    VOLVO          0  ...         NaN         1674  105427130  38.416481
#
#    Longitude        LocationTimeStamp                  Name     Value  \
# 0 -84.626851  2015-02-21 11:34:25.000             IgnStatus     False
# 1 -84.626851  2015-02-21 11:35:10.000     EngineOilPressure         0
# 2 -87.767361  2015-02-21 11:35:26.000  EngineOilTemperature  96.74375
# 3 -87.767361  2015-02-21 11:36:08.000    TurboBoostPressure         0
# 4 -89.442638  2015-02-21 11:39:37.000            EngineLoad        11
#
#    FaultId FullDerate
# 0      1.0          0
# 1      1.0          0
# 2      1.0          0
# 3      1.0          0
# 4      1.0          0
#
# [5 rows x 24 columns]

# %% [markdown]
# This data is in long-format, so each FaultId can have potentially many diagnostic values.
#
# **Note:** Not all diagnostic values are recorded for all faults, so you will have a large number of missing values.
#
# For example, for the second fault code in our dataset, only the ignition status and lamp status were recorded.

# %%
diagnostics.loc[diagnostics['FaultId'] == 2]
# Out:
#     Id        Name Value  FaultId
# 21  22   IgnStatus  True        2
# 22  23  LampStatus  1279        2

# %% [markdown]
# Finally, we can get a little bit more information about the different fault codes from the Service Fault Codes spreadsheet.

# %%
sfc = pd.read_excel("../data/Service Fault Codes_1_0_0_167.xlsx")
sfc.head()
# Out:
# c:\Users\irela\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Data Validation extension is not supported and will be removed
#   for idx, row in parser.parse():
#   Published in CES 14602  Cummins Fault Code  Revision         PID  \
# 0                      Y                 111       167  Not Mapped
# 1                      Y                 112       167  Not Mapped
# 2                      Y                 113       167  Not Mapped
# 3                      Y                 114       167  Not Mapped
# 4                      Y                 115       167         190
#
#           SID         MID  J1587 FMI  SPN  J1939 FMI J2012 Pcode Lamp Color  \
# 0         254           0         12  629         12       P0606        Red
# 1          20         128          7  635          7  Not Mapped        Red
# 2          20         128          3  635          3  Not Mapped      Amber
# 3          20         128          4  635          4  Not Mapped      Amber
# 4  Not Mapped  Not Mapped          2  612          2       P0008        Red
#
#        Lamp Device                                Cummins Description  \
# 0  Stop / Shutdown  Engine Control Module Critical Internal Failur...
# 1  Stop / Shutdown  Engine Timing Actuator Driver Circuit - Mechan...
# 2          Warning  Engine Timing Actuator Driver Circuit - Voltag...
# 3          Warning  Engine Timing Actuator Driver Circuit - Voltag...
# 4  Stop / Shutdown  Engine Magnetic Speed/Position Lost Both of Tw...
#
#                                Algorithm Description
# 0  Error internal to the ECM related to memory ha...
# 1  Mechanical failure in the engine timing actuat...
# 2  High signal voltage detected at the engine tim...
# 3  Low voltage detected at the engine timing actu...
# 4  The ECM has detected that the primary and back...

# %%
sfc['FullDerate'] = sfc['SPN'].apply(lambda x: 1 if x == 5246 else 0)

# %%
sfc.head()
# Out:
#   Published in CES 14602  Cummins Fault Code  Revision         PID  \
# 0                      Y                 111       167  Not Mapped
# 1                      Y                 112       167  Not Mapped
# 2                      Y                 113       167  Not Mapped
# 3                      Y                 114       167  Not Mapped
# 4                      Y                 115       167         190
#
#           SID         MID  J1587 FMI  SPN  J1939 FMI J2012 Pcode Lamp Color  \
# 0         254           0         12  629         12       P0606        Red
# 1          20         128          7  635          7  Not Mapped        Red
# 2          20         128          3  635          3  Not Mapped      Amber
# 3          20         128          4  635          4  Not Mapped      Amber
# 4  Not Mapped  Not Mapped          2  612          2       P0008        Red
#
#        Lamp Device                                Cummins Description  \
# 0  Stop / Shutdown  Engine Control Module Critical Internal Failur...
# 1  Stop / Shutdown  Engine Timing Actuator Driver Circuit - Mechan...
# 2          Warning  Engine Timing Actuator Driver Circuit - Voltag...
# 3          Warning  Engine Timing Actuator Driver Circuit - Voltag...
# 4  Stop / Shutdown  Engine Magnetic Speed/Position Lost Both of Tw...
#
#                                Algorithm Description  FullDerate
# 0  Error internal to the ECM related to memory ha...           0
# 1  Mechanical failure in the engine timing actuat...           0
# 2  High signal voltage detected at the engine tim...           0
# 3  Low voltage detected at the engine timing actu...           0
# 4  The ECM has detected that the primary and back...           0

# %% [markdown]
# For a large number of fault codes, there are multiple records. For example, if we look at the rows for the first fault in our dataset, we see that there are two rows.

# %%
(
    sfc
    .loc[sfc['SPN'] == 111]
    .loc[sfc['J1939 FMI'] == 17]
)
# Out:
#      Published in CES 14602  Cummins Fault Code  Revision         PID  \
# 1589                      Y                2448       167         111
# 3540                      Y                5167       167  Not Mapped
#
#              SID         MID  J1587 FMI  SPN  J1939 FMI J2012 Pcode  \
# 1589  Not Mapped  Not Mapped          1  111         17       P2560
# 3540  Not Mapped  Not Mapped          1  111         17  Not Mapped
#
#        Lamp Color  Lamp Device  \
# 1589  Maintenance  Maintenance
# 3540        Amber      Warning
#
#                                     Cummins Description  \
# 1589  Coolant Level - Data Valid But Below Normal Op...
# 3540  Coolant Level - Data Valid But Below Normal Op...
#
#                    Algorithm Description
# 1589  Low engine coolant level detected.
# 3540                                 NaN

# %% [markdown]
# Or even more.

# %%
(
    sfc
    .loc[sfc['SPN'] == 629]
    .loc[sfc['J1939 FMI'] == 12]
)
# Out:
#      Published in CES 14602  Cummins Fault Code  Revision         PID  SID  \
# 0                         Y                 111       167  Not Mapped  254
# 180                       Y                 343       167  Not Mapped  254
# 689                       Y                1116       167  Not Mapped  254
# 854                       Y                1388       167  Not Mapped  254
# 1019                      Y                1597       167  Not Mapped  254
#
#      MID  J1587 FMI  SPN  J1939 FMI J2012 Pcode   Lamp Color      Lamp Device  \
# 0      0         12  629         12       P0606          Red  Stop / Shutdown
# 180    0         12  629         12       P0607        Amber          Warning
# 689    0         12  629         12  Not Mapped        Amber          Warning
# 854    0         12  629         12  Not Mapped          NaN              NaN
# 1019   0         12  629         12  Not Mapped  Maintenance      Maintenance
#
#                                     Cummins Description  \
# 0     Engine Control Module Critical Internal Failur...
# 180   Engine Control Module Warning Internal Hardwar...
# 689   Engine Control Module Critical Internal Failur...
# 854   Engine Control Module Data Lost - Bad Intellig...
# 1019  Engine Control Module Critical Internal Failur...
#
#                                   Algorithm Description
# 0     Error internal to the ECM related to memory ha...
# 180         ECM power supply errors have been detected.
# 689                  ECM Internal failure has occurred.
# 854                         The ECM data has been lost.
# 1019          The ECM has occurred an internal failure.
